# %% [markdown]
# <a href="https://colab.research.google.com/github/srilakshmi-2003/DLT-LAB/blob/main/srilakshmi-2003/DLT-LAB/Regularization_on_Multiclass_classification_using_Reuters_Newswire_Dataset(10).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 0s 0us/step

# %%
import numpy as np
from keras.utils import to_categorical
def OneHotEncoding_fn(ReutersData, dimension=10000):
    # 8982 x 10k matrix of zeros
    OneHotEncoded_Data = np.zeros((len(ReutersData), dimension))
    for i, sequence in enumerate(ReutersData):
        #Selectively make indices as 1 based on availability of word in the review.
        OneHotEncoded_Data[i, sequence] = 1.
    return OneHotEncoded_Data
x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)
y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
from keras import models
from keras import layers
from keras import regularizers
model = models.Sequential()
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics
X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]
model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])
history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 3s 120ms/step - loss: 7.2487 - categorical_accuracy: 0.4767 - val_loss: 3.8036 - val_categorical_accuracy: 0.5537
# Epoch 2/25
# 16/16 [==============================] - 1s 54ms/step - loss: 3.4493 - categorical_accuracy: 0.5589 - val_loss: 3.1414 - val_categorical_accuracy: 0.5975
# Epoch 3/25
# 16/16 [==============================] - 1s 51ms/step - loss: 3.0681 - categorical_accuracy: 0.5881 - val_loss: 2.8790 - val_categorical_accuracy: 0.6075
# Epoch 4/25
# 16/16 [==============================] - 1s 54ms/step - loss: 2.8518 - categorical_accuracy: 0.6195 - val_loss: 2.7228 - val_categorical_accuracy: 0.6612
# Epoch 5/25
# 16/16 [==============================] - 1s 51ms/step - loss: 2.7021 - categorical_accuracy: 0.6430 - val_loss: 2.5857 - val_categorical_accuracy: 0.6538
# Epoch 6/25
# 16/16 [==============================] - 1s 50ms/step - loss: 2.5776 - categorical_accuracy: 0.6585 - val_loss: 2.4669 - val_categorical_accuracy: 0.6737
# Epoch 7/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.4776 - categorical_accuracy: 0.6657 - val_loss: 2.4215 - val_categorical_accuracy: 0.6762
# Epoch 8/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.3935 - categorical_accuracy: 0.6742 - val_loss: 2.3258 - val_categorical_accuracy: 0.6913
# Epoch 9/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.3282 - categorical_accuracy: 0.6781 - val_loss: 2.2713 - val_categorical_accuracy: 0.6825
# Epoch 10/25
# 16/16 [==============================] - 1s 51ms/step - loss: 2.2661 - categorical_accuracy: 0.6872 - val_loss: 2.1992 - val_categorical_accuracy: 0.6938
# Epoch 11/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.2193 - categorical_accuracy: 0.6880 - val_loss: 2.1915 - val_categorical_accuracy: 0.6888
# Epoch 12/25
# 16/16 [==============================] - 1s 48ms/step - loss: 2.1769 - categorical_accuracy: 0.6907 - val_loss: 2.1307 - val_categorical_accuracy: 0.6975
# Epoch 13/25
# 16/16 [==============================] - 1s 54ms/step - loss: 2.1374 - categorical_accuracy: 0.6923 - val_loss: 2.1024 - val_categorical_accuracy: 0.6913
# Epoch 14/25
# 16/16 [==============================] - 1s 86ms/step - loss: 2.1134 - categorical_accuracy: 0.6940 - val_loss: 2.0683 - val_categorical_accuracy: 0.6925
# Epoch 15/25
# 16/16 [==============================] - 1s 93ms/step - loss: 2.0830 - categorical_accuracy: 0.6968 - val_loss: 2.0695 - val_categorical_accuracy: 0.6988
# Epoch 16/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.0718 - categorical_accuracy: 0.6931 - val_loss: 2.0399 - val_categorical_accuracy: 0.6950
# Epoch 17/25
# 16/16 [==============================] - 1s 50ms/step - loss: 2.0449 - categorical_accuracy: 0.6971 - val_loss: 2.0140 - val_categorical_accuracy: 0.6975
# Epoch 18/25
# 16/16 [==============================] - 1s 49ms/step - loss: 2.0268 - categorical_accuracy: 0.6987 - val_loss: 1.9970 - val_categorical_accuracy: 0.6975
# Epoch 19/25
# 16/16 [==============================] - 1s 51ms/step - loss: 2.0122 - categorical_accuracy: 0.6993 - val_loss: 1.9838 - val_categorical_accuracy: 0.7050
# Epoch 20/25
# 16/16 [==============================] - 1s 55ms/step - loss: 1.9907 - categorical_accuracy: 0.7006 - val_loss: 1.9660 - val_categorical_accuracy: 0.7038
# Epoch 21/25
# 16/16 [==============================] - 1s 49ms/step - loss: 1.9751 - categorical_accuracy: 0.7003 - val_loss: 1.9642 - val_categorical_accuracy: 0.7025
# Epoch 22/25
# 16/16 [==============================] - 1s 58ms/step - loss: 1.9593 - categorical_accuracy: 0.7048 - val_loss: 1.9423 - val_categorical_accuracy: 0.7013
# Epoch 23/25
# 16/16 [==============================] - 1s 56ms/step - loss: 1.9477 - categorical_accuracy: 0.7046 - val_loss: 1.9307 - val_categorical_accuracy: 0.7025
# Epoch 24/25
# 16/16 [==============================] - 1s 51ms/step - loss: 1.9326 - categorical_accuracy: 0.7050 - val_loss: 1.9161 - val_categorical_accuracy: 0.7063
# Epoch 25/25
# 16/16 [==============================] - 1s 52ms/step - loss: 1.9163 - categorical_accuracy: 0.7072 - val_loss: 1.9325 - val_categorical_accuracy: 0.7000

# %%
import matplotlib.pyplot as plt
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
